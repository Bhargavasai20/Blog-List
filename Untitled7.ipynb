# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavasai20/Blog-List/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/KwaiVGI/LivePortrait.git
# %cd LivePortrait
# Out:
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.
# /content/LivePortrait

# %%
# !pip install -r requirements.txt

# %%
# !pip install huggingface_hub

# %%
# !huggingface-cli download KwaiVGI/LivePortrait --local-dir pretrained_weights --exclude "*.git*" "README.md" "docs"
# Out:
# Fetching 20 files:   0% 0/20 [00:00<?, ?it/s]Downloading 'liveportrait/base_models/appearance_feature_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/w2JquOgGo_-zOZp03SpATaJOQmc=.5279bb8654293dbdf327030b397f107237dd9212fb11dd75b83dfb635211ceb5.incomplete'
# ...
#
# motion_extractor.pth:   0% 0.00/113M [00:00<?, ?B/s]
#
# inference.gif:   0% 0.00/820k [00:00<?, ?B/s]
#
#
# warping_module.pth:   0% 0.00/182M [00:00<?, ?B/s]
#
#
#
# appearance_feature_extractor.pth:   0% 0.00/3.39M [00:00<?, ?B/s]
#
#
#
#
# 2d106det.onnx:   0% 0.00/5.03M [00:00<?, ?B/s]
#
#
#
#
#
# spade_generator.pth:   0% 0.00/222M [00:00<?, ?B/s]Downloading 'docs/showcase2.gif' to 'pretrained_weights/.cache/huggingface/download/docs/ovU00xd4wrM1WlqZO5_wVkCk_ec=.eb1fffb139681775780b2956e7d0289f55d199c1a3e14ab263887864d4b0d586.incomplete'
# inference.gif: 100% 820k/820k [00:00<00:00, 18.2MB/s]
# Download complete. Moving file to pretrained_weights/docs/inference.gif
# ...

# %%
import time
import os

start_time = time.time()
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d13.mp4
print(f"Inference time: {time.time() - start_time:.2f} seconds")
# Out:
# [08:06:12] Load appearance_feature_extractor from    ]8;id=768210;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=403636;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=37518;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=410063;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [08:06:13] Load warping_module from                  ]8;id=888978;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=258775;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
# ...

# %%
from IPython.display import Video
Video("output.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python inference.py \
  -s assets/examples/source/s9.jpg \
  -d assets/examples/driving/d13.mp4 \
  --result_dir results/
# Out:
# ╭─ Unrecognized options ─────────────────────╮
# │ Unrecognized options: --result-dir         │
# │ ────────────────────────────────────────── │
# │ For full helptext, run inference.py --help │
# ╰────────────────────────────────────────────╯

# %%
# !head -n 50 inference.py
# Out:
# # coding: utf-8
#
# """
# The entrance of humans
# """
#
# import os
# import os.path as osp
# import tyro
# import subprocess
# from src.config.argument_config import ArgumentConfig
# from src.config.inference_config import InferenceConfig
# from src.config.crop_config import CropConfig
# from src.live_portrait_pipeline import LivePortraitPipeline
#
#
# def partial_fields(target_class, kwargs):
#     return target_class(**{k: v for k, v in kwargs.items() if hasattr(target_class, k)})
#
#
# def fast_check_ffmpeg():
#     try:
#         subprocess.run(["ffmpeg", "-version"], capture_output=True, check=True)
#         return True
#     except:
#         return False
#
#
# def fast_check_args(args: ArgumentConfig):
#     if not osp.exists(args.source):
#         raise FileNotFoundError(f"source info not found: {args.source}")
#     if not osp.exists(args.driving):
#         raise FileNotFoundError(f"driving info not found: {args.driving}")
#
#
# def main():
#     # set tyro theme
# ...

# %%
cv2.VideoWriter(...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-aa49a3be54b0> in <cell line: 0>()
# ----> 1 cv2.VideoWriter(...)
#
# NameError: name 'cv2' is not defined

# %%
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d13.mp4
# Out:
# [08:15:09] Load appearance_feature_extractor from    ]8;id=985373;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=954067;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
# [08:15:10] Load motion_extractor from                ]8;id=647972;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=856775;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
#            Load warping_module from                  ]8;id=42460;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=512916;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
# ...

# %%
# !find . -name "*.mp4"
# Out:
# ./assets/examples/driving/d11.mp4
# ./assets/examples/driving/d10.mp4
# ./assets/examples/driving/d18.mp4
# ./assets/examples/driving/d6.mp4
# ./assets/examples/driving/d13.mp4
# ./assets/examples/driving/d14.mp4
# ./assets/examples/driving/d19.mp4
# ./assets/examples/driving/d12.mp4
# ./assets/examples/driving/d9.mp4
# ./assets/examples/driving/d0.mp4
# ./assets/examples/driving/d3.mp4
# ./assets/examples/driving/d20.mp4
# ./assets/examples/source/s32.mp4
# ./assets/examples/source/s20.mp4
# ./assets/examples/source/s13.mp4
# ./assets/examples/source/s18.mp4
# ./assets/examples/source/s29.mp4
# ./animations/s9--d13.mp4
# ./animations/s9--d13_concat.mp4

# %%
./output/s9_d13.mp4
# Out:
#   File "<ipython-input-16-c366dd293eb3>", line 1
#     ./output/s9_d13.mp4
#     ^
# SyntaxError: invalid syntax

# %%
# !find . -name "*.mp4"
# Out:
# ./assets/examples/driving/d11.mp4
# ./assets/examples/driving/d10.mp4
# ./assets/examples/driving/d18.mp4
# ./assets/examples/driving/d6.mp4
# ./assets/examples/driving/d13.mp4
# ./assets/examples/driving/d14.mp4
# ./assets/examples/driving/d19.mp4
# ./assets/examples/driving/d12.mp4
# ./assets/examples/driving/d9.mp4
# ./assets/examples/driving/d0.mp4
# ./assets/examples/driving/d3.mp4
# ./assets/examples/driving/d20.mp4
# ./assets/examples/source/s32.mp4
# ./assets/examples/source/s20.mp4
# ./assets/examples/source/s13.mp4
# ./assets/examples/source/s18.mp4
# ./assets/examples/source/s29.mp4
# ./animations/s9--d13.mp4
# ./animations/s9--d13_concat.mp4

# %%
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d13.mp4
# Out:
# [08:21:40] Load appearance_feature_extractor from    ]8;id=108815;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=223189;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=745537;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=500116;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [08:21:41] Load warping_module from                  ]8;id=456437;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=4170;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
# ...

# %%
from IPython.display import Video
Video("animations/s9--d13.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
