# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavasai20/Blog-List/blob/main/LivePortrait.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/KwaiVGI/LivePortrait
# !cd LivePortrait
# Out:
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.

# %%
# %cd LivePortrait/
# Out:
# /content/LivePortrait

# %%
# !pip install -r requirements.txt

# %%
# !pip install -U "huggingface_hub[cli]
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
# !huggingface-cli download KwaiVGI/LivePortrait --local-dir pretrained_weights --exclude "*.git*" "README.md" "docs"
# Out:
# Fetching 20 files:   0% 0/20 [00:00<?, ?it/s]Downloading 'docs/inference.gif' to 'pretrained_weights/.cache/huggingface/download/docs/ke8qy6KU2hXc8UMbe9pzGl7iH4Q=.e1316eca5556ba5a8da7c53bcadbc1df26aa822bbde68fbad94813139803d0c6.incomplete'
# ...
#
# det_10g.onnx:   0% 0.00/16.9M [00:00<?, ?B/s]
#
# appearance_feature_extractor.pth:   0% 0.00/3.39M [00:00<?, ?B/s]
#
#
# showcase2.gif:   0% 0.00/2.88M [00:00<?, ?B/s]
#
#
#
# inference.gif:   0% 0.00/820k [00:00<?, ?B/s]
#
#
#
#
# spade_generator.pth:   0% 0.00/222M [00:00<?, ?B/s]
#
#
#
#
#
# inference.gif: 100% 820k/820k [00:00<00:00, 24.4MB/s]
# Download complete. Moving file to pretrained_weights/docs/inference.gif
# appearance_feature_extractor.pth: 100% 3.39M/3.39M [00:00<00:00, 53.1MB/s]
# showcase2.gif: 100% 2.88M/2.88M [00:00<00:00, 47.9MB/s]
# Download complete. Moving file to pretrained_weights/docs/showcase2.gif
# Download complete. Moving file to pretrained_weights/liveportrait/base_models/appearance_feature_extractor.pth
# ...
#
# ...

# %%
# !mkdir -p assets/examples/source assets/examples/driving
# !wget -O assets/examples/source/s9.jpg https://github.com/KwaiVGI/LivePortrait/raw/main/assets/examples/source/s9.jpg
# !wget -O assets/examples/driving/d0.mp4 https://github.com/KwaiVGI/LivePortrait/raw/main/assets/examples/driving/d0.mp4
# Out:
# --2025-06-05 09:38:22--  https://github.com/KwaiVGI/LivePortrait/raw/main/assets/examples/source/s9.jpg
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/KwaiVGI/LivePortrait/main/assets/examples/source/s9.jpg [following]
# --2025-06-05 09:38:23--  https://raw.githubusercontent.com/KwaiVGI/LivePortrait/main/assets/examples/source/s9.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 442850 (432K) [image/jpeg]
# Saving to: ‘assets/examples/source/s9.jpg’
#
# assets/examples/sou 100%[===================>] 432.47K  --.-KB/s    in 0.04s
#
# ...

# %%
import time

start = time.time()
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d0.mp4
end = time.time()
print(f"Inference time (original): {end - start:.2f} seconds")
# Out:
# [09:47:06] Load appearance_feature_extractor from    ]8;id=301012;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=661554;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=259536;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=755397;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [09:47:07] Load warping_module from                  ]8;id=717964;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=698217;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
# ...

# %%
from IPython.display import Video
Video("animations/s9--d0.mp4", width=512, embed=True)
# Out:
# <video controls  width="512" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
start = time.time()

# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d0.mp4 --no_flag_pasteback --flag_do_torch_compile
end = time.time()
print(f"Inference time (optimized): {end - start:.2f} seconds")
# Out:
# [09:50:35] Load appearance_feature_extractor from    ]8;id=239020;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=659777;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=122773;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=476024;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [09:50:36] Load warping_module from                  ]8;id=366217;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=637963;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
# ...

# %%
Video("animations/s9--d0.mp4", width=512, embed=True)
# Out:
# <video controls  width="512" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
